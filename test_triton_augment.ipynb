# %% [markdown]
# # Triton-Augment GPU Testing
#
# This notebook tests Triton-Augment on Google Colab with GPU support.
#
# **Before running**: Go to `Runtime` → `Change runtime type` → Select `GPU` (T4, V100, or A100)
#
# Author: yuhezhang-ai

# %% [markdown]
# ## Step 1: Check GPU Availability

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")
else:
    print("❌ No GPU! Go to Runtime → Change runtime type → Select GPU")
